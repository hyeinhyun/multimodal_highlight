# %% [markdown]
# # data

# %%
import numpy as np
import pickle
with open('/home/ubuntu/gangmin/tsvt/multimodal/data/video_frames.pickle',"rb") as f:
    video_frames = pickle.load(f)

# %%
import numpy as np
import pickle
with open('/home/ubuntu/gangmin/tsvt/multimodal/data/audio_frames.pickle',"rb") as f:
    audio_frames = pickle.load(f)

# %%
with open('/home/ubuntu/gangmin/tsvt/multimodal/data/chat_frames.pickle','rb') as f:
    chat_frames = pickle.load(f)

# %% [markdown]
# # label

# %%
import numpy as np
import pickle
import copy
with open('/home/ubuntu/gangmin/tsvt/multimodal/label/label.pickle',"rb") as f:
    label = pickle.load(f)

# %% [markdown]
# # and concatenation video+audio

# %%
and_video_audio= {}
for key in video_frames.keys():
    and_video_audio[key] = copy.deepcopy(video_frames[key])
    for i,v in enumerate(video_frames[key]):
        if and_video_audio[key][i] == 1 and audio_frames[key][i] == 1:
            and_video_audio[key][i] = 1
        else:
            and_video_audio[key][i] = 0

# %%
average = [0,0,0,0,0]
for key in label.keys():
    TP = len(np.where((and_video_audio[key]==1)&(label[key]==1)==True)[0])
    FP = len(np.where((and_video_audio[key]==1)&(label[key]==0)==True)[0])
    TN = len(np.where((and_video_audio[key]==0)&(label[key]==0)==True)[0])
    FN = len(np.where((and_video_audio[key]==0)&(label[key]==1)==True)[0])

    
    precision = TP/(TP+FP)
    recall = TP/(TP+FN)
    accuracy = (TP+TN) / (TP+FN+FP+TN)
    
    if precision==0 and recall == 0:
        print('!')
    else:
    
        f1 = (2*precision*recall / (precision + recall))
    
        print('precision : {}, recall : {}, f1 : {}, accuracy : {}'.format(precision,recall,f1,accuracy))
        average[0]+= precision
        average[1] += recall
        average[2] += f1
        average[3] += accuracy
        average[4]+=1
# Out:
# precision : 0.7732558139534884, recall : 0.6288416075650118, f1 : 0.6936114732724902, accuracy : 0.8991848991848992
# precision : 0.5435684647302904, recall : 0.5177865612648221, f1 : 0.5303643724696356, accuracy : 0.8914873713751169
# precision : 0.4153225806451613, recall : 0.44396551724137934, f1 : 0.42916666666666664, accuracy : 0.8496982995063083
# precision : 0.7178217821782178, recall : 0.43543543543543545, f1 : 0.5420560747663551, accuracy : 0.8549437537004144
# precision : 0.7349397590361446, recall : 0.21107266435986158, f1 : 0.3279569892473118, accuracy : 0.8529411764705882
# precision : 0.4879518072289157, recall : 0.4263157894736842, f1 : 0.45505617977528084, accuracy : 0.8908272369161508
# precision : 0.6891891891891891, recall : 0.31875, f1 : 0.43589743589743585, accuracy : 0.857451403887689
# precision : 0.5949367088607594, recall : 0.15112540192926044, f1 : 0.24102564102564103, accuracy : 0.822754491017964
# ...

# %%
print('precision : {}, recall : {}, f1 : {}, accuracy : {}'.format(average[0]/average[4],average[1]/average[4],average[2]/average[4],average[3]/average[4]))
# Out:
# precision : 0.6027503486111482, recall : 0.354014172586856, f1 : 0.43453199545630267, accuracy : 0.8410653603001217

# %% [markdown]
# # xor concatenation video+audio

# %%
xor_video_audio= {}
for key in video_frames.keys():
    xor_video_audio[key] = copy.deepcopy(video_frames[key])
    for i,v in enumerate(video_frames[key]):
        if xor_video_audio[key][i] == 0 and audio_frames[key][i] == 1:
            xor_video_audio[key][i] = 1

# %%
average = [0,0,0,0,0]
for key in label.keys():
    TP = len(np.where((xor_video_audio[key]==1)&(label[key]==1)==True)[0])
    FP = len(np.where((xor_video_audio[key]==1)&(label[key]==0)==True)[0])
    TN = len(np.where((xor_video_audio[key]==0)&(label[key]==0)==True)[0])
    FN = len(np.where((xor_video_audio[key]==0)&(label[key]==1)==True)[0])

    
    precision = TP/(TP+FP)
    recall = TP/(TP+FN)
    accuracy = (TP+TN) / (TP+FN+FP+TN)
    
    if precision==0 and recall == 0:
        print('!')
    else:
    
        f1 = (2*precision*recall / (precision + recall))
    
        print('precision : {}, recall : {}, f1 : {}, accuracy : {}'.format(precision,recall,f1,accuracy))
        average[0]+= precision
        average[1] += recall
        average[2] += f1
        average[3] += accuracy
        average[4]+=1
# Out:
# precision : 0.24052132701421802, recall : 0.9598108747044918, f1 : 0.384651823780199, accuracy : 0.44272844272844275
# precision : 0.16842847075405215, recall : 0.9446640316205533, f1 : 0.28588516746411485, accuracy : 0.441534144059869
# precision : 0.16053249804228661, recall : 0.8836206896551724, f1 : 0.2717031146454606, accuracy : 0.3971475589687329
# precision : 0.2980318650421743, recall : 0.954954954954955, f1 : 0.45428571428571435, accuracy : 0.5476613380698638
# precision : 0.20229405630865485, recall : 0.671280276816609, f1 : 0.3108974358974359, accuracy : 0.49411764705882355
# precision : 0.15692821368948248, recall : 0.9894736842105263, f1 : 0.2708933717579251, accuracy : 0.4305008441193022
# precision : 0.22433132010353754, recall : 0.8125, f1 : 0.3515889114266396, accuracy : 0.4821814254859611
# precision : 0.18712871287128713, recall : 0.6077170418006431, f1 : 0.2861468584405753, accuracy : 0.4353293413173653
# ...

# %%
print('precision : {}, recall : {}, f1 : {}, accuracy : {}'.format(average[0]/average[4],average[1]/average[4],average[2]/average[4],average[3]/average[4]))
# Out:
# precision : 0.23237780098790056, recall : 0.8419177292590893, f1 : 0.3614145496504405, accuracy : 0.4723554217595783

# %% [markdown]
# # and concatenation video+chat

# %%
and_video_chat= {}
for key in video_frames.keys():
    and_video_chat[key] = copy.deepcopy(video_frames[key])
    for i,v in enumerate(video_frames[key]):
        if and_video_chat[key][i] == 1 and chat_frames[key][i] == 1:
            and_video_chat[key][i] = 1
        else:
            and_video_chat[key][i] = 0

# %%
average = [0,0,0,0,0]
for key in label.keys():
    TP = len(np.where((and_video_chat[key]==1)&(label[key]==1)==True)[0])
    FP = len(np.where((and_video_chat[key]==1)&(label[key]==0)==True)[0])
    TN = len(np.where((and_video_chat[key]==0)&(label[key]==0)==True)[0])
    FN = len(np.where((and_video_chat[key]==0)&(label[key]==1)==True)[0])

    
    precision = TP/(TP+FP)
    recall = TP/(TP+FN)
    accuracy = (TP+TN) / (TP+FN+FP+TN)
    
    if precision==0 and recall == 0:
        print('!')
    else:
    
        f1 = (2*precision*recall / (precision + recall))
    
        print('precision : {}, recall : {}, f1 : {}, accuracy : {}'.format(precision,recall,f1,accuracy))
        average[0]+= precision
        average[1] += recall
        average[2] += f1
        average[3] += accuracy
        average[4]+=1
# Out:
# precision : 0.8760330578512396, recall : 0.25059101654846333, f1 : 0.3897058823529412, accuracy : 0.8575718575718576
# precision : 0.8839285714285714, recall : 0.391304347826087, f1 : 0.5424657534246576, accuracy : 0.921889616463985
# precision : 0.8723404255319149, recall : 0.17672413793103448, f1 : 0.2939068100358423, accuracy : 0.8919363686231486
# precision : 0.845360824742268, recall : 0.24624624624624625, f1 : 0.38139534883720927, accuracy : 0.84251036116045
# precision : 0.9166666666666666, recall : 0.07612456747404844, f1 : 0.14057507987220447, accuracy : 0.841764705882353
# precision : 0.673469387755102, recall : 0.3473684210526316, f1 : 0.4583333333333333, accuracy : 0.9122115925717501
# precision : 0.7272727272727273, recall : 0.075, f1 : 0.13597733711048157, accuracy : 0.8353131749460043
# precision : 0.7857142857142857, recall : 0.03536977491961415, f1 : 0.06769230769230769, accuracy : 0.818562874251497
# ...

# %%
print('precision : {}, recall : {}, f1 : {}, accuracy : {}'.format(average[0]/average[4],average[1]/average[4],average[2]/average[4],average[3]/average[4]))
# Out:
# precision : 0.7609931772066437, recall : 0.1674480749693921, f1 : 0.26043251038052934, accuracy : 0.8399087025407395

# %% [markdown]
# # xor concatenation video+chat

# %%
xor_video_chat= {}
for key in video_frames.keys():
    xor_video_chat[key] = copy.deepcopy(video_frames[key])
    for i,v in enumerate(video_frames[key]):
        if xor_video_chat[key][i] == 0 and chat_frames[key][i] == 1:
            xor_video_chat[key][i] = 1

# %%
average = [0,0,0,0,0]
for key in label.keys():
    TP = len(np.where((xor_video_chat[key]==1)&(label[key]==1)==True)[0])
    FP = len(np.where((xor_video_chat[key]==1)&(label[key]==0)==True)[0])
    TN = len(np.where((xor_video_chat[key]==0)&(label[key]==0)==True)[0])
    FN = len(np.where((xor_video_chat[key]==0)&(label[key]==1)==True)[0])

    
    precision = TP/(TP+FP)
    recall = TP/(TP+FN)
    accuracy = (TP+TN) / (TP+FN+FP+TN)
    
    if precision==0 and recall == 0:
        print('!')
    else:
    
        f1 = (2*precision*recall / (precision + recall))
    
        print('precision : {}, recall : {}, f1 : {}, accuracy : {}'.format(precision,recall,f1,accuracy))
        average[0]+= precision
        average[1] += recall
        average[2] += f1
        average[3] += accuracy
        average[4]+=1
# Out:
# precision : 0.6288998357963875, recall : 0.9054373522458629, f1 : 0.7422480620155039, accuracy : 0.8858858858858859
# precision : 0.41353383458646614, recall : 0.8695652173913043, f1 : 0.5605095541401274, accuracy : 0.8386342376052386
# precision : 0.3897550111358575, recall : 0.7543103448275862, f1 : 0.5139500734214391, accuracy : 0.818431157432803
# precision : 0.6223628691983122, recall : 0.8858858858858859, f1 : 0.7311028500619579, accuracy : 0.8715216104203671
# precision : 0.7025862068965517, recall : 0.5640138408304498, f1 : 0.6257197696737045, accuracy : 0.8852941176470588
# precision : 0.46534653465346537, recall : 0.9894736842105263, f1 : 0.632996632996633, accuracy : 0.8773213280810355
# precision : 0.6155913978494624, recall : 0.715625, f1 : 0.661849710982659, accuracy : 0.8736501079913607
# precision : 0.541501976284585, recall : 0.4405144694533762, f1 : 0.4858156028368794, accuracy : 0.8263473053892215
# ...

# %%
print('precision : {}, recall : {}, f1 : {}, accuracy : {}'.format(average[0]/average[4],average[1]/average[4],average[2]/average[4],average[3]/average[4]))
# Out:
# precision : 0.5289741514803573, recall : 0.7335638480245323, f1 : 0.6057112548206469, accuracy : 0.8334849889278777

# %% [markdown]
# # and concatenation audio+chat

# %%
and_audio_chat= {}
for key in audio_frames.keys():
    and_audio_chat[key] = copy.deepcopy(audio_frames[key])
    for i,v in enumerate(audio_frames[key]):
        if and_audio_chat[key][i] == 1 and chat_frames[key][i] == 1:
            and_audio_chat[key][i] = 1
        else:
            and_audio_chat[key][i] = 0

# %%
average = [0,0,0,0,0]
for key in label.keys():
    TP = len(np.where((and_audio_chat[key]==1)&(label[key]==1)==True)[0])
    FP = len(np.where((and_audio_chat[key]==1)&(label[key]==0)==True)[0])
    TN = len(np.where((and_audio_chat[key]==0)&(label[key]==0)==True)[0])
    FN = len(np.where((and_audio_chat[key]==0)&(label[key]==1)==True)[0])

    
    precision = TP/(TP+FP)
    recall = TP/(TP+FN)
    accuracy = (TP+TN) / (TP+FN+FP+TN)
    
    if precision==0 and recall == 0:
        print('!')
    else:
    
        f1 = (2*precision*recall / (precision + recall))
    
        print('precision : {}, recall : {}, f1 : {}, accuracy : {}'.format(precision,recall,f1,accuracy))
        average[0]+= precision
        average[1] += recall
        average[2] += f1
        average[3] += accuracy
        average[4]+=1
# Out:
# precision : 0.6184971098265896, recall : 0.25295508274231676, f1 : 0.35906040268456374, accuracy : 0.8361218361218361
# precision : 0.5241379310344828, recall : 0.30039525691699603, f1 : 0.38190954773869346, accuracy : 0.8849391955098223
# precision : 0.6438356164383562, recall : 0.2025862068965517, f1 : 0.3081967213114754, accuracy : 0.884256719692814
# precision : 0.6483516483516484, recall : 0.17717717717717718, f1 : 0.2783018867924528, accuracy : 0.8188277087033747
# precision : 0.5, recall : 0.03460207612456748, f1 : 0.06472491909385114, accuracy : 0.83
# precision : 0.5774647887323944, recall : 0.21578947368421053, f1 : 0.31417624521072796, accuracy : 0.899268429938098
# precision : 0.37777777777777777, recall : 0.053125, f1 : 0.09315068493150684, accuracy : 0.8212742980561555
# precision : 0.2, recall : 0.022508038585209004, f1 : 0.04046242774566475, accuracy : 0.8011976047904191
# ...

# %%
print('precision : {}, recall : {}, f1 : {}, accuracy : {}'.format(average[0]/average[4],average[1]/average[4],average[2]/average[4],average[3]/average[4]))
# Out:
# precision : 0.45362282132443993, recall : 0.12057629526141163, f1 : 0.18591669709181868, accuracy : 0.8160297390325528

# %% [markdown]
# # xor concatenation audio+chat

# %%
xor_audio_chat= {}
for key in audio_frames.keys():
    xor_audio_chat[key] = copy.deepcopy(audio_frames[key])
    for i,v in enumerate(audio_frames[key]):
        if xor_audio_chat[key][i] == 0 and chat_frames[key][i] == 1:
            xor_audio_chat[key][i] = 1

# %%
average = [0,0,0,0,0]
for key in label.keys():
    TP = len(np.where((xor_audio_chat[key]==1)&(label[key]==1)==True)[0])
    FP = len(np.where((xor_audio_chat[key]==1)&(label[key]==0)==True)[0])
    TN = len(np.where((xor_audio_chat[key]==0)&(label[key]==0)==True)[0])
    FN = len(np.where((xor_audio_chat[key]==0)&(label[key]==1)==True)[0])

    
    precision = TP/(TP+FP)
    recall = TP/(TP+FN)
    accuracy = (TP+TN) / (TP+FN+FP+TN)
    
    if precision==0 and recall == 0:
        print('!')
    else:
    
        f1 = (2*precision*recall / (precision + recall))
    
        print('precision : {}, recall : {}, f1 : {}, accuracy : {}'.format(precision,recall,f1,accuracy))
        average[0]+= precision
        average[1] += recall
        average[2] += f1
        average[3] += accuracy
        average[4]+=1
# Out:
# precision : 0.21900566393958465, recall : 0.8226950354609929, f1 : 0.3459244532803181, accuracy : 0.43543543543543545
# precision : 0.14416475972540047, recall : 0.7470355731225297, f1 : 0.24168797953964197, accuracy : 0.4452759588400374
# precision : 0.14913793103448275, recall : 0.7456896551724138, f1 : 0.24856321839080456, accuracy : 0.42622051563357105
# precision : 0.23485653560042508, recall : 0.6636636636636637, f1 : 0.3469387755102041, accuracy : 0.507400828892836
# precision : 0.15402298850574714, recall : 0.46366782006920415, f1 : 0.2312338222605695, accuracy : 0.4758823529411765
# precision : 0.10295519542421354, recall : 0.5684210526315789, f1 : 0.17433414043583537, accuracy : 0.42431063590320767
# precision : 0.15369836695485112, recall : 0.5, f1 : 0.23512123438648055, accuracy : 0.4379049676025918
# precision : 0.1489817792068596, recall : 0.44694533762057875, f1 : 0.22347266881028938, accuracy : 0.4215568862275449
# ...

# %%
print('precision : {}, recall : {}, f1 : {}, accuracy : {}'.format(average[0]/average[4],average[1]/average[4],average[2]/average[4],average[3]/average[4]))
# Out:
# precision : 0.18895795136276877, recall : 0.6147249774043583, f1 : 0.28645880111476435, accuracy : 0.4554856188066126

# %% [markdown]
# # and concatenation video+audio+chat

# %%
and_video_audio_chat= {}
for key in video_frames.keys():
    and_video_audio_chat[key] = copy.deepcopy(video_frames[key])
    for i,v in enumerate(video_frames[key]):
        if and_video_audio_chat[key][i] == 1 and chat_frames[key][i] == 1 and audio_frames[key][i] == 1:
            and_video_audio_chat[key][i] = 1
        else:
            and_video_audio_chat[key][i] = 0

# %%
average = [0,0,0,0,0]
for key in label.keys():
    TP = len(np.where((and_video_audio_chat[key]==1)&(label[key]==1)==True)[0])
    FP = len(np.where((and_video_audio_chat[key]==1)&(label[key]==0)==True)[0])
    TN = len(np.where((and_video_audio_chat[key]==0)&(label[key]==0)==True)[0])
    FN = len(np.where((and_video_audio_chat[key]==0)&(label[key]==1)==True)[0])

    
    precision = TP/(TP+FP)
    recall = TP/(TP+FN)
    accuracy = (TP+TN) / (TP+FN+FP+TN)
    
    if precision==0 and recall == 0:
        print('!')
    else:
    
        f1 = (2*precision*recall / (precision + recall))
    
        print('precision : {}, recall : {}, f1 : {}, accuracy : {}'.format(precision,recall,f1,accuracy))
        average[0]+= precision
        average[1] += recall
        average[2] += f1
        average[3] += accuracy
        average[4]+=1
# Out:
# precision : 0.8876404494382022, recall : 0.1867612293144208, f1 : 0.30859375, accuracy : 0.8481338481338482
# precision : 0.8987341772151899, recall : 0.28063241106719367, f1 : 0.42771084337349397, accuracy : 0.9111318989710009
# precision : 0.8823529411764706, recall : 0.12931034482758622, f1 : 0.22556390977443608, accuracy : 0.8869994514536478
# precision : 0.8571428571428571, recall : 0.14414414414414414, f1 : 0.2467866323907455, accuracy : 0.8265245707519242
# precision : 0.9090909090909091, recall : 0.03460207612456748, f1 : 0.06666666666666667, accuracy : 0.8352941176470589
# precision : 0.7272727272727273, recall : 0.21052631578947367, f1 : 0.32653061224489793, accuracy : 0.9071468767585819
# precision : 0.7333333333333333, recall : 0.034375, f1 : 0.06567164179104477, accuracy : 0.8309935205183585
# precision : 0.5, recall : 0.00964630225080386, f1 : 0.01892744479495268, accuracy : 0.8137724550898203
# ...

# %%
print('precision : {}, recall : {}, f1 : {}, accuracy : {}'.format(average[0]/average[4],average[1]/average[4],average[2]/average[4],average[3]/average[4]))
# Out:
# precision : 0.7676331210812462, recall : 0.09200695811603675, f1 : 0.15812333995531813, accuracy : 0.8304436348474008

# %% [markdown]
# # xor-2 concatenation video+audio+chat

# %%
xor2_video_audio_chat= {}
for key in video_frames.keys():
    xor2_video_audio_chat[key] = copy.deepcopy(video_frames[key])
    for i,v in enumerate(video_frames[key]):
        if (xor2_video_audio_chat[key][i] == 1 and chat_frames[key][i] == 1) or (xor2_video_audio_chat[key][i] == 1 and audio_frames[key][i] == 1) or (audio_frames[key][i] == 1 and chat_frames[key][i] == 1):
            xor2_video_audio_chat[key][i] = 1
        else:
            xor2_video_audio_chat[key][i] = 0

# %%
average = [0,0,0,0,0]
for key in label.keys():
    TP = len(np.where((xor2_video_audio_chat[key]==1)&(label[key]==1)==True)[0])
    FP = len(np.where((xor2_video_audio_chat[key]==1)&(label[key]==0)==True)[0])
    TN = len(np.where((xor2_video_audio_chat[key]==0)&(label[key]==0)==True)[0])
    FN = len(np.where((xor2_video_audio_chat[key]==0)&(label[key]==1)==True)[0])

    
    precision = TP/(TP+FP)
    recall = TP/(TP+FN)
    accuracy = (TP+TN) / (TP+FN+FP+TN)
    
    if precision==0 and recall == 0:
        print('!')
    else:
    
        f1 = (2*precision*recall / (precision + recall))
    
        print('precision : {}, recall : {}, f1 : {}, accuracy : {}'.format(precision,recall,f1,accuracy))
        average[0]+= precision
        average[1] += recall
        average[2] += f1
        average[3] += accuracy
        average[4]+=1
# Out:
# precision : 0.6978260869565217, recall : 0.7588652482269503, f1 : 0.7270668176670442, accuracy : 0.8966108966108967
# precision : 0.4823529411764706, recall : 0.6482213438735178, f1 : 0.5531197301854974, accuracy : 0.8760523854069223
# precision : 0.43666666666666665, recall : 0.5646551724137931, f1 : 0.49248120300751885, accuracy : 0.8518924849149753
# precision : 0.6834532374100719, recall : 0.5705705705705706, f1 : 0.6219312602291326, accuracy : 0.8632326820603907
# precision : 0.6952380952380952, recall : 0.25259515570934254, f1 : 0.37055837563451777, accuracy : 0.8541176470588235
# precision : 0.48, recall : 0.5684210526315789, f1 : 0.5204819277108433, accuracy : 0.8880135059088351
# precision : 0.6173469387755102, recall : 0.378125, f1 : 0.46899224806201545, accuracy : 0.8520518358531317
# precision : 0.5086206896551724, recall : 0.18971061093247588, f1 : 0.2763466042154567, accuracy : 0.8149700598802395
# ...

# %%
print('precision : {}, recall : {}, f1 : {}, accuracy : {}'.format(average[0]/average[4],average[1]/average[4],average[2]/average[4],average[3]/average[4]))
# Out:
# precision : 0.555526786610867, recall : 0.4572438711147288, f1 : 0.4918567189168069, accuracy : 0.8361405405481449

# %% [markdown]
# # xor concatenation video+audio+chat

# %%
xor_video_audio_chat= {}
for key in video_frames.keys():
    xor_video_audio_chat[key] = copy.deepcopy(video_frames[key])
    for i,v in enumerate(video_frames[key]):
        if xor_video_audio_chat[key][i] == 0 and chat_frames[key][i] == 0 and audio_frames[key][i] == 0:
            xor_video_audio_chat[key][i] = 0
        else:
            xor_video_audio_chat[key][i] = 1

# %%
average = [0,0,0,0,0]
for key in label.keys():
    TP = len(np.where((xor_video_audio_chat[key]==1)&(label[key]==1)==True)[0])
    FP = len(np.where((xor_video_audio_chat[key]==1)&(label[key]==0)==True)[0])
    TN = len(np.where((xor_video_audio_chat[key]==0)&(label[key]==0)==True)[0])
    FN = len(np.where((xor_video_audio_chat[key]==0)&(label[key]==1)==True)[0])

    
    precision = TP/(TP+FP)
    recall = TP/(TP+FN)
    accuracy = (TP+TN) / (TP+FN+FP+TN)
    
    if precision==0 and recall == 0:
        print('!')
    else:
    
        f1 = (2*precision*recall / (precision + recall))
    
        print('precision : {}, recall : {}, f1 : {}, accuracy : {}'.format(precision,recall,f1,accuracy))
        average[0]+= precision
        average[1] += recall
        average[2] += f1
        average[3] += accuracy
        average[4]+=1
# Out:
# precision : 0.2381786339754816, recall : 0.9645390070921985, f1 : 0.38202247191011235, accuracy : 0.4337194337194337
# precision : 0.16563997262149213, recall : 0.9565217391304348, f1 : 0.2823803967327888, accuracy : 0.4246959775491113
# precision : 0.16318638824439288, recall : 0.9094827586206896, f1 : 0.27672131147540985, accuracy : 0.3949533735600658
# precision : 0.29219600725952816, recall : 0.9669669669669669, f1 : 0.44878048780487806, accuracy : 0.5316755476613381
# precision : 0.21370143149284254, recall : 0.7231833910034602, f1 : 0.32991318074191006, accuracy : 0.5005882352941177
# precision : 0.1549876339653751, recall : 0.9894736842105263, f1 : 0.26799714896650034, accuracy : 0.4220596510973551
# precision : 0.2222222222222222, recall : 0.825, f1 : 0.35013262599469497, accuracy : 0.4708423326133909
# precision : 0.1951923076923077, recall : 0.6527331189710611, f1 : 0.30051813471502586, accuracy : 0.4341317365269461
# ...

# %%
print('precision : {}, recall : {}, f1 : {}, accuracy : {}'.format(average[0]/average[4],average[1]/average[4],average[2]/average[4],average[3]/average[4]))
# Out:
# precision : 0.23256775039664765, recall : 0.866481341786626, f1 : 0.36403411906124655, accuracy : 0.4625927444729617
